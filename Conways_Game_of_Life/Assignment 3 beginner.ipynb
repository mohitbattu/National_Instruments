# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x=np.linspace(0,100,20)
print(x)
plt.plot(x)
plt.xlabel('x')
# Out:
# [  0.           5.26315789  10.52631579  15.78947368  21.05263158
#   26.31578947  31.57894737  36.84210526  42.10526316  47.36842105
#   52.63157895  57.89473684  63.15789474  68.42105263  73.68421053
#   78.94736842  84.21052632  89.47368421  94.73684211 100.        ]
# Text(0.5, 0, 'x')

# %%
x=np.linspace(0,10,10)
y=x**5
plt.plot(x,y,'black')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
x=np.linspace(0,10,10)
y=x**5
plt.plot(x,y,'ro')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
x=np.linspace(0,10,10)
y=x**5
plt.plot(x,y,'gs')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
x = np.arange(0., 10.,0.2)
y=x**2
y1=x**3
f, (ax1, ax2) = plt.subplots(2,1, sharex=True)
ax1.plot(x,y)
ax2.plot(x,y1)

# %%
x = np.arange(0., 10.,0.2)
y=x**2
y1=x**3
f, ax = plt.subplots(2,1, sharex=True)
ax[0].plot(x,y)
ax[1].plot(x,y1)
plt.xlim(5,6)
plt.ylim(20,100)
# Out:
# (20, 100)

# %%
x=np.linspace(0,10,10)
y=x*2
f,ax = plt.subplots(3)
ax[0].plot(x,y)
ax[1].scatter(x,y)
ax[2].bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
from PIL import Image
import requests
from io import BytesIO
url =["https://i.ibb.co/TwsG391/Screenshot-from-2020-05-21-19-17-26.png",
"https://i.ibb.co/bR4XSQ8/Screenshot-from-2020-05-23-00-03-32.png",
"https://i.ibb.co/SQbPCDH/Screenshot-from-2020-05-22-17-30-38.png",
"https://i.ibb.co/JntTQ9v/Screenshot-from-2020-05-22-18-35-22.png"]
for i in url:
    response = requests.get(i)
    img = Image.open(BytesIO(response.content))
    plt.imshow(img)

# %%
s = pd.Series(np.random.randint(5, size=10))
s
# Out:
# 0    3
# 1    4
# 2    1
# 3    2
# 4    0
# 5    2
# 6    4
# 7    3
# 8    2
# 9    4
# dtype: int32

# %%
df = pd.read_csv("https://raw.githubusercontent.com/cognibot-official/data/master/occupation.csv",
index_col = 'user_id')

# %%
df[:10]
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator     5201
# 9         29      M        student     1002
# 10        53      M         lawyer    90703

# %%
df[-10:]
# Out:
#          age gender     occupation zip_code
# user_id
# 934       61      M       engineer    22902
# 935       42      M         doctor    66221
# 936       24      M          other    32789
# 937       48      M       educator    98072
# 938       38      F     technician    55038
# 939       26      F        student    33319
# 940       32      M  administrator     2215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841

# %%
df.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
m=df.as_matrix()
# Out:
# C:\Users\Phanith Daruvuri\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
df.iloc[:4,:3]
# Out:
#          age gender  occupation
# user_id
# 1         24      M  technician
# 2         53      F       other
# 3         23      M      writer
# 4         24      M  technician

# %%
df.iloc[:6,:3]
# Out:
#          age gender  occupation
# user_id
# 1         24      M  technician
# 2         53      F       other
# 3         23      M      writer
# 4         24      M  technician
# 5         33      F       other
# 6         42      M   executive

# %%
df[df.occupation=='writer']
# Out:
#          age gender occupation zip_code status
# user_id
# 3         23      M     writer    32067   poor
# 21        26      M     writer    30068   poor
# 22        25      M     writer    40206   poor
# 28        32      M     writer    55369   poor
# 50        21      M     writer    52245   poor
# 122       32      F     writer    22206   poor
# 196       49      M     writer    55105   poor
# 199       30      M     writer    17604   poor
# 201       27      M     writer    E2A4H   poor
# 236       44      F     writer    53214   poor
# 264       36      F     writer    90064   poor
# 293       24      M     writer    60804   poor
# 370       52      M     writer     8534   poor
# 385       36      M     writer    10003   poor
# 389       44      F     writer    83702   poor
# 390       42      F     writer    85016   poor
# 392       52      M     writer    59801   poor
# 445       21      M     writer    92653   poor
# 464       60      M     writer    94583   poor
# ...

# %%
status=[]
for i in range(len(m)):
    if m[i][2]=='engineer' or m[i][2]=='programmer' or m[i][2]=='scientist':
        if m[i][0]<30:
            status.append('rich')
        else:
            status.append('poor')
    else:
        status.append('poor')
df['status']=status
df
# Out:
#          age gender     occupation zip_code status
# user_id
# 1         24      M     technician    85711   poor
# 2         53      F          other    94043   poor
# 3         23      M         writer    32067   poor
# 4         24      M     technician    43537   poor
# 5         33      F          other    15213   poor
# ...      ...    ...            ...      ...    ...
# 939       26      F        student    33319   poor
# 940       32      M  administrator     2215   poor
# 941       20      M        student    97229   poor
# 942       48      F      librarian    78209   poor
# 943       22      M        student    77841   poor
#
# [943 rows x 5 columns]

# %%
df.age.mean()
# Out:
# 34.05196182396607

# %%
df.describe()
# Out:
#               age
# count  943.000000
# mean    34.051962
# std     12.192740
# min      7.000000
# 25%     25.000000
# 50%     31.000000
# 75%     43.000000
# max     73.000000

# %%
print("studnts mean of age",df[df.occupation=='student'].age.mean())
print("lawyer mean of age",df[df.occupation=='lawyer'].age.mean())
print("engineer mean of age",df[df.occupation=='engineer'].age.mean())
# Out:
# studnts mean of age 22.081632653061224
# lawyer mean of age 36.75
# engineer mean of age 36.38805970149254

# %%
occupations=list(set(df.occupation))
min=99
for i in occupations:
    if df[df.occupation==i].age.mean()<min:
        min=df[df.occupation==i].age.mean()
        ans=i
print("the field with youngest people is",ans)
# Out:
# the field with youngest people is student

# %%
for i in occupations:
    df1=df[df.occupation==i]
    if df1[df1.gender=='M'].size > df1[df1.gender=='F'].size:
        print(i+' has more men than women')
    else:
        print(i+' has more women than men')
# Out:
# lawyer has more men than women
# student has more men than women
# healthcare has more women than men
# executive has more men than women
# programmer has more men than women
# salesman has more men than women
# librarian has more women than men
# none has more men than women
# educator has more men than women
# artist has more men than women
# entertainment has more men than women
# marketing has more men than women
# engineer has more men than women
# scientist has more men than women
# other has more men than women
# administrator has more men than women
# writer has more men than women
# retired has more men than women
# doctor has more men than women
# technician has more men than women
# homemaker has more women than men

# %%
# Out:
#   File "<ipython-input-103-e2c998a1396b>", line 1
#     "
#      ^
# SyntaxError: EOL while scanning string literal
